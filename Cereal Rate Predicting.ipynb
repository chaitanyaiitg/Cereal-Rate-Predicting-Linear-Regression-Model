# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns

# %%
df=pd.read_csv('F:\Data_Science\Cereal\Cereal.csv')

# %%
df
# Out:
#                          name mfr type  calories  protein  fat  sodium  fiber  \
# 0                   100% Bran   N    C        70        4    1     130   10.0
# 1           100% Natural Bran   Q    C       120        3    5      15    2.0
# 2                    All-Bran   K    C        70        4    1     260    9.0
# 3   All-Bran with Extra Fiber   K    C        50        4    0     140   14.0
# 4              Almond Delight   R    C       110        2    2     200    1.0
# ..                        ...  ..  ...       ...      ...  ...     ...    ...
# 72                    Triples   G    C       110        2    1     250    0.0
# 73                       Trix   G    C       110        1    1     140    0.0
# 74                 Wheat Chex   R    C       100        3    1     230    3.0
# 75                   Wheaties   G    C       100        3    1     200    3.0
# 76        Wheaties Honey Gold   G    C       110        2    1     200    1.0
#
# ...

# %%
df.shape
# Out:
# (77, 16)

# %%
df.columns
# Out:
# Index(['name', 'mfr', 'type', 'calories', 'protein', 'fat', 'sodium', 'fiber',
#        'carbo', 'sugars', 'potass', 'vitamins', 'shelf', 'weight', 'cups',
#        'rating'],
#       dtype='object')

# %%
print('carbo ',df['carbo'].unique())
print('sugars ', df['sugars'].unique())
print('potass ',df['potass'].unique())
# Out:
# carbo  [ 5.   8.   7.  14.  10.5 11.  18.  15.  13.  12.  17.  22.  21.  10.
#  11.5 20.  16.  13.5 -1.  23.  19.   9. ]
# sugars  [ 6  8  5  0 10 14 12  1  9  7 13  3  2 11 15  4 -1]
# potass  [280 135 320 330  -1  70  30 100 125 190  35 105  45  55  25  20  65 160
#  120  80 200  40  85  90  60  95 170 130 260  15  50 110 240 140 230 115]

# %%
df[df['potass']==-1]
# Out:
#                       name mfr type  calories  protein  fat  sodium  fiber  \
# 4           Almond Delight   R    C       110        2    2     200    1.0
# 20  Cream of Wheat (Quick)   N    H       100        3    0      80    1.0
#
#     carbo  sugars  potass  vitamins  shelf  weight  cups     rating
# 4    14.0       8      -1        25      3     1.0  0.75  34.384843
# 20   21.0       0      -1         0      2     1.0  1.00  64.533816

# %%
df.dtypes
# Out:
# name         object
# mfr          object
# type         object
# calories      int64
# protein       int64
# fat           int64
# sodium        int64
# fiber       float64
# carbo       float64
# sugars        int64
# potass        int64
# vitamins      int64
# shelf         int64
# weight      float64
# cups        float64
# rating      float64
# dtype: object

# %%
df['mfr'].value_counts()
# Out:
# K    23
# G    22
# P     9
# R     8
# Q     8
# N     6
# A     1
# Name: mfr, dtype: int64

# %%
sns.countplot(df['mfr'])
plt.xlabel('Manufacturer')
plt.ylabel('No of Cereal Types Produced')
plt.title('No of Cereals Produced by Manufacturers', color='r')
# Out:
# Text(0.5, 1.0, 'No of Cereals Produced by Manufacturers')

# %%
sns.catplot(x = "mfr", y ="rating", data= df.sort_values('mfr'),kind='boxen',height=5,aspect=2)

# %%
df['type'].value_counts()
# Out:
# C    74
# H     3
# Name: type, dtype: int64

# %%
df['name'].value_counts()
# Out:
# Shredded Wheat               1
# Clusters                     1
# Grape Nuts Flakes            1
# Shredded Wheat spoon size    1
# Apple Jacks                  1
#                             ..
# Rice Chex                    1
# Golden Crisp                 1
# Total Corn Flakes            1
# Cracklin' Oat Bran           1
# Honey Graham Ohs             1
# Name: name, Length: 77, dtype: int64

# %%
plt.figure(figsize=(20,25))
sns.barplot(y='name', x='rating',data=df.sort_values(['rating'],ascending=False))

# %%
df.isnull().sum()
# Out:
# name        0
# mfr         0
# type        0
# calories    0
# protein     0
# fat         0
# sodium      0
# fiber       0
# carbo       0
# sugars      0
# potass      0
# vitamins    0
# shelf       0
# weight      0
# cups        0
# rating      0
# dtype: int64

# %%
df.head()
# Out:
#                         name mfr type  calories  protein  fat  sodium  fiber  \
# 0                  100% Bran   N    C        70        4    1     130   10.0
# 1          100% Natural Bran   Q    C       120        3    5      15    2.0
# 2                   All-Bran   K    C        70        4    1     260    9.0
# 3  All-Bran with Extra Fiber   K    C        50        4    0     140   14.0
# 4             Almond Delight   R    C       110        2    2     200    1.0
#
#    carbo  sugars  potass  vitamins  shelf  weight  cups     rating
# 0    5.0       6     280        25      3     1.0  0.33  68.402973
# 1    8.0       8     135         0      3     1.0  1.00  33.983679
# 2    7.0       5     320        25      3     1.0  0.33  59.425505
# 3    8.0       0     330        25      3     1.0  0.50  93.704912
# 4   14.0       8      -1        25      3     1.0  0.75  34.384843

# %%
df.describe()
# Out:
#          calories    protein        fat      sodium      fiber      carbo  \
# count   77.000000  77.000000  77.000000   77.000000  77.000000  77.000000
# mean   106.883117   2.545455   1.012987  159.675325   2.151948  14.597403
# std     19.484119   1.094790   1.006473   83.832295   2.383364   4.278956
# min     50.000000   1.000000   0.000000    0.000000   0.000000  -1.000000
# 25%    100.000000   2.000000   0.000000  130.000000   1.000000  12.000000
# 50%    110.000000   3.000000   1.000000  180.000000   2.000000  14.000000
# 75%    110.000000   3.000000   2.000000  210.000000   3.000000  17.000000
# max    160.000000   6.000000   5.000000  320.000000  14.000000  23.000000
#
#           sugars      potass    vitamins      shelf     weight       cups  \
# count  77.000000   77.000000   77.000000  77.000000  77.000000  77.000000
# mean    6.922078   96.077922   28.246753   2.207792   1.029610   0.821039
# std     4.444885   71.286813   22.342523   0.832524   0.150477   0.232716
# ...

# %%
df['carbo']=np.where(df['carbo']==-1,0,df['carbo'])
df['sugars']=np.where(df['sugars']==-1,0,df['sugars'])
df['potass']=np.where(df['potass']==-1,df['potass'].mode()[0],df['potass'])

# %%
df
# Out:
#                          name mfr type  calories  protein  fat  sodium  fiber  \
# 0                   100% Bran   N    C        70        4    1     130   10.0
# 1           100% Natural Bran   Q    C       120        3    5      15    2.0
# 2                    All-Bran   K    C        70        4    1     260    9.0
# 3   All-Bran with Extra Fiber   K    C        50        4    0     140   14.0
# 4              Almond Delight   R    C       110        2    2     200    1.0
# ..                        ...  ..  ...       ...      ...  ...     ...    ...
# 72                    Triples   G    C       110        2    1     250    0.0
# 73                       Trix   G    C       110        1    1     140    0.0
# 74                 Wheat Chex   R    C       100        3    1     230    3.0
# 75                   Wheaties   G    C       100        3    1     200    3.0
# 76        Wheaties Honey Gold   G    C       110        2    1     200    1.0
#
# ...

# %%
df[df['vitamins']==0]
# Out:
#                          name mfr type  calories  protein  fat  sodium  fiber  \
# 1           100% Natural Bran   Q    C       120        3    5      15    2.0
# 20     Cream of Wheat (Quick)   N    H       100        3    0      80    1.0
# 54                Puffed Rice   Q    C        50        1    0       0    0.0
# 55               Puffed Wheat   Q    C        50        2    0       0    1.0
# 57             Quaker Oatmeal   Q    H       100        5    2       0    2.7
# 63             Shredded Wheat   N    C        80        2    0       0    3.0
# 64     Shredded Wheat 'n'Bran   N    C        90        3    0       0    4.0
# 65  Shredded Wheat spoon size   N    C        90        3    0       0    3.0
#
#     carbo  sugars  potass  vitamins  shelf  weight  cups     rating
# 1     8.0       8     135         0      3    1.00  1.00  33.983679
# 20   21.0       0      35         0      2    1.00  1.00  64.533816
# ...

# %%
df
# Out:
#                          name mfr type  calories  protein  fat  sodium  fiber  \
# 0                   100% Bran   N    C        70        4    1     130   10.0
# 1           100% Natural Bran   Q    C       120        3    5      15    2.0
# 2                    All-Bran   K    C        70        4    1     260    9.0
# 3   All-Bran with Extra Fiber   K    C        50        4    0     140   14.0
# 4              Almond Delight   R    C       110        2    2     200    1.0
# ..                        ...  ..  ...       ...      ...  ...     ...    ...
# 72                    Triples   G    C       110        2    1     250    0.0
# 73                       Trix   G    C       110        1    1     140    0.0
# 74                 Wheat Chex   R    C       100        3    1     230    3.0
# 75                   Wheaties   G    C       100        3    1     200    3.0
# 76        Wheaties Honey Gold   G    C       110        2    1     200    1.0
#
# ...

# %%
df_final=df.iloc[:,3:16]
df_final
# Out:
#     calories  protein  fat  sodium  fiber  carbo  sugars  potass  vitamins  \
# 0         70        4    1     130   10.0    5.0       6     280        25
# 1        120        3    5      15    2.0    8.0       8     135         0
# 2         70        4    1     260    9.0    7.0       5     320        25
# 3         50        4    0     140   14.0    8.0       0     330        25
# 4        110        2    2     200    1.0   14.0       8      35        25
# ..       ...      ...  ...     ...    ...    ...     ...     ...       ...
# 72       110        2    1     250    0.0   21.0       3      60        25
# 73       110        1    1     140    0.0   13.0      12      25        25
# 74       100        3    1     230    3.0   17.0       3     115        25
# 75       100        3    1     200    3.0   17.0       3     110        25
# 76       110        2    1     200    1.0   16.0       8      60        25
#
#     shelf  weight  cups     rating
# ...

# %%
df.columns
# Out:
# Index(['name', 'mfr', 'type', 'calories', 'protein', 'fat', 'sodium', 'fiber',
#        'carbo', 'sugars', 'potass', 'vitamins', 'shelf', 'weight', 'cups',
#        'rating'],
#       dtype='object')

# %%
cols=['calories', 'protein', 'fat', 'sodium', 'fiber','carbo', 'sugars', 'potass', 'vitamins', 'shelf', 'weight','cups']
for i in list(cols):
    sns.lmplot(y='rating',x=i,data=df,height=5,aspect=1)
    plt.title("%s vs %s" %('rating', i))

# %%
X=df.iloc[:,3:15]

# %%
X
# Out:
#     calories  protein  fat  sodium  fiber  carbo  sugars  potass  vitamins  \
# 0         70        4    1     130   10.0    5.0       6     280        25
# 1        120        3    5      15    2.0    8.0       8     135         0
# 2         70        4    1     260    9.0    7.0       5     320        25
# 3         50        4    0     140   14.0    8.0       0     330        25
# 4        110        2    2     200    1.0   14.0       8      35        25
# ..       ...      ...  ...     ...    ...    ...     ...     ...       ...
# 72       110        2    1     250    0.0   21.0       3      60        25
# 73       110        1    1     140    0.0   13.0      12      25        25
# 74       100        3    1     230    3.0   17.0       3     115        25
# 75       100        3    1     200    3.0   17.0       3     110        25
# 76       110        2    1     200    1.0   16.0       8      60        25
#
#     shelf  weight  cups
# 0       3     1.0  0.33
# ...

# %%
y=df['rating']
y
# Out:
# 0     68.402973
# 1     33.983679
# 2     59.425505
# 3     93.704912
# 4     34.384843
#         ...
# 72    39.106174
# 73    27.753301
# 74    49.787445
# 75    51.592193
# 76    36.187559
# Name: rating, Length: 77, dtype: float64

# %%
plt.figure(figsize = (20,20))
sns.heatmap(df_final.corr(), annot = True, cmap = "RdYlGn")
plt.show()

# %%
# Important feature using ExtraTreesRegressor

from sklearn.ensemble import ExtraTreesRegressor
selection = ExtraTreesRegressor()
selection.fit(X, y)
# Out:
# ExtraTreesRegressor()

# %%
print(selection.feature_importances_)
# Out:
# [0.23000015 0.05978468 0.03496965 0.04085469 0.09081094 0.02568524
#  0.43181023 0.03391696 0.02125743 0.01114504 0.00455642 0.01520858]

# %%
plt.figure(figsize=(15,10))
feature_imp=pd.Series(selection.feature_importances_, index=X.columns)
feature_imp.nlargest(27).plot(kind='barh')

# %%
from sklearn.svm import SVR
from sklearn.ensemble import RandomForestRegressor
from sklearn.tree import DecisionTreeRegressor
from sklearn.linear_model import Lasso
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import RandomizedSearchCV
from sklearn.model_selection import ShuffleSplit
from sklearn.model_selection import GridSearchCV
from sklearn.model_selection import cross_val_score
from sklearn.preprocessing import StandardScaler
from xgboost import XGBRegressor

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test=train_test_split(X,y,test_size=0.25,random_state=10)

# %%
s=StandardScaler()
X_train=s.fit_transform(X_train)
X_test=s.transform(X_test)

# %%
algo=[]
value=[]
def cross_val_score_model(model,name):
    cv = ShuffleSplit(n_splits=5, test_size=0.25, random_state=10)
    cv_score=cross_val_score(model,X,y,cv=cv).mean()
    print('CV_Score' + ' '+ str(name) +': '+ str(cv_score))
    algo.append(name)
    value.append(cv_score)

cross_val_score_model(RandomForestRegressor(),'RandomForestRegressor')
cross_val_score_model(XGBRegressor(),'XGBRegressor')
cross_val_score_model(LinearRegression(),'LinearRegression')
cross_val_score_model(Lasso(),'Lasso')
# Out:
# CV_Score RandomForestRegressor: 0.7097217259671249
# CV_Score XGBRegressor: 0.7619535896817259
# CV_Score LinearRegression: 0.9995516470553371
# CV_Score Lasso: 0.9587893164645471

# %%
sns.barplot(x=value,y=algo)
plt.show()

# %%
#Linear Regression is best model

# %%
from sklearn.metrics import r2_score
lr=LinearRegression()
lr.fit(X_train,y_train)
lr_y_pred=lr.predict(X_test)
score=r2_score(y_test,lr_y_pred)
score
# Out:
# 0.999463164738058

# %%
df_final.iloc[50]
# Out:
# calories     90.000000
# protein       3.000000
# fat           0.000000
# sodium      170.000000
# fiber         3.000000
# carbo        18.000000
# sugars        2.000000
# potass       90.000000
# vitamins     25.000000
# shelf         3.000000
# weight        1.000000
# cups          1.000000
# rating       59.642837
# Name: 50, dtype: float64

# %%
a=[[90,3,0,170,3,18,2,90,25,3,1,1]]
a=s.transform(a)
b=lr.predict(a)
b
# Out:
# array([59.64172232])

# %%
final=pd.DataFrame({'actual':y_test, 'prediction':lr_y_pred})

# %%
final
# Out:
#        actual  prediction
# 63  68.235885   68.213694
# 3   93.704912   93.692137
# 35  21.871292   21.866234
# 21  46.895644   46.909431
# 19  40.448772   40.456444
# 38  36.523683   36.534109
# 39  36.471512   36.497741
# 26  58.345141   58.354900
# 32  52.076897   52.086951
# 6   33.174094   33.187009
# 2   59.425505   59.418914
# 41  45.328074   45.314206
# 74  49.787445   49.790583
# 20  64.533816   63.291949
# 4   34.384843   33.167463
# 55  63.005645   62.987814
# 45  34.139765   34.325070
# 70  28.592785   28.574337
# 44  37.136863   37.324507
# 42  26.734515   26.737539

# %%
sns.distplot(y_test-lr_y_pred)

# %%
plt.scatter(y_test,lr_y_pred)
